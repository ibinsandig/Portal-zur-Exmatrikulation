# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 150

# %%
img = cv.imread("bild_49.jpg")
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

fig = plt.imshow(img_gray, cmap = 'gray', vmin=0, vmax=255)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
img_gauss = cv.GaussianBlur(img_gray, (5, 5), sigmaX=0, sigmaY=0)
img_gray_gauss = cv.resize(img_gauss, (int(img_gauss.shape[1]/2), int(img_gauss.shape[0]/2)), interpolation=cv.INTER_LINEAR)

fig = plt.imshow(img_gauss, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
img_gray.shape
# Out:
# (480, 640)
